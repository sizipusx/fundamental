# %%
import sqlite3
import pandas as pd

rcon = sqlite3.connect('C:/Users/sizip/fundamental/files/rebuild_house.db')

# %%
file_path = "C:/Users/sizip/OneDriveData/개인/data/부동산 기본 파일/매물시세/2024-02-16_재개발분양권_전체시세.xlsx"
rebuild_dict = pd.ExcelFile(file_path)
total_df =  rebuild_dict.parse("Sheet2", parse_dates=False) # dtype={'구분': str})
sum_df =  rebuild_dict.parse("Sheet3", parse_dates=False) #, dtype={'구분': str})
total_df.tail()
# Out:
#              매물코드        지역코드   시도명     지역명   매물정보                  단지명     동  \
# 42656  2403904418  5214011100  전라북도     익산시  NDOC1                   세경   13동
# 42657  2407579712  5214011100  전라북도     익산시    DOC                   세경   13동
# 42658  2407361800  4711325000  경상북도  포항시 북구  NDOC1              한화포레나포항  102동
# 42659  2404076601  4688025000  전라남도     장성군    DOC  대광로제비앙장성센텀스카이(민간임대)  103동
# 42660  2407979685  4711325000  경상북도  포항시 북구   NONE              힐스테이트초곡  115동
#
#       매물방식    매물종류  공급면적  ...                                        특이사항  \
# 42656   매매     재건축    27  ...                두산건설 모델하우스오픈  동산동 최고의 위치 재건축
# 42657   매매     재건축    27  ...                     재건축 입주권 101동 3층 59타입 확정
# 42658   매매  아파트분양권   142  ...                                         NaN
# 42659   매매  아파트분양권   113  ...                    테라스 구조. 단지조경. 25년2월 입주예정
# 42660   매매  아파트분양권   112  ...  분양권 초급매 마피3천\r\n초곡힐스테이트 34A 방3,화2, 남서향, 24
#
#             확인매물 거래가(만) 한글거래가액                                 태그  \
# 42656  24.01.23.   3000  3,000    ['25년이상', '필로티', '소형평수', '방두개']
# 42657  24.02.15.   2500  2,500  ['25년이상', '소형평수', '방두개', '화장실한개']
# 42658  24.02.14.   2386  2,386   ['2년이내', '대단지', '대형평수', '방네개이상']
# 42659  24.01.23.   2100  2,100    ['2년이내', '테라스', '화장실두개', '방세개']
# 42660  24.02.16.      0    NaN       ['2년이내', '대단지', '급매', '방세개']
#
#                  부동산 매물방향         위도          경도        거래가재산정
# 42656  제일풍경채공인중개사사무소   남향  35.935140  126.966251   3000.000000
# 42657     공인중개사사무소선우   남향  35.935140  126.966251   3000.000000
# 42658    더조은부동산중개사무소   남향  36.070514  129.331788  48508.740741
# 42659  벧엘부동산공인중개사사무소  남서향  35.306693  126.790788  21426.666667
# 42660     서광공인중개사사무소  남서향  36.092467  129.336112  35459.653061
#
# [5 rows x 22 columns]

# %%
# import pandas as pd
# df = pd.read_csv('/content/2022-09-18_재개발분양권_매물요약.csv')
sum_df.to_sql(name="sum", con=rcon, if_exists='replace')
total_df.to_sql(name="total", con=rcon, if_exists='replace')
# Out:
# c:\Anaconda3\lib\site-packages\pandas\core\generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
rdf = pd.read_sql("SELECT * FROM 'sum'", rcon)
rdf
# Out:
#       index  Unnamed: 0         단지명  공급면적          지역코드   시도명    전용면적  \
# 0         0           0      에테르노청담   391  1.168010e+09   서울시  273.38
# 1         1           1      에테르노청담   567  1.168010e+09   서울시  273.38
# 2         2           3      에테르노청담   344  1.168010e+09   서울시  244.85
# 3         3           4  한남2재정비촉진구역   658  1.117013e+09   서울시  325.33
# 4         4           5  한남5재정비촉진구역   899  1.117014e+09   서울시  165.85
# ...     ...         ...         ...   ...           ...   ...     ...
# 5549   5549        5549        한우2차    49  4.719011e+09  경상북도   40.09
# 5550   5550        5550          세경    58  5.214011e+09  전라북도   49.32
# 5551   5551        5551   삼척센트럴두산위브   110  5.123012e+09   강원도   84.55
# 5552   5552        5552        한우2차    40  4.719011e+09  경상북도   31.46
# 5553   5553        5553          세경    27  5.214011e+09  전라북도   20.52
#
#       공급면적(평)      공급평당가(만)        거래가(만)  물건수      최고값      최저값  평균전세가율  \
# 0         118  27118.640000  3.200000e+06    1  3200000  3200000     NaN
# 1         172  18604.650000  3.200000e+06    2  3200000  3200000     NaN
# 2         104  21153.850000  2.200000e+06    3  2200000  2200000     NaN
# 3         199  10050.250000  2.000000e+06    1  2000000  2000000     NaN
# 4         272   7169.120000  1.950000e+06    1  1950000  1950000     NaN
# ...       ...           ...           ...  ...      ...      ...     ...
# 5549       15    388.886667  5.833333e+03    6     7000     5000     NaN
# 5550       18    315.204211  5.673684e+03   19     8500     4200     NaN
# 5551       33    157.970000  5.213000e+03    1     5213     5213   4.732
# 5552       12    340.278333  4.083333e+03    6     5300     3100   0.735
# 5553        8    375.000000  3.000000e+03    3     3500     2500     NaN
#
#              위도          경도    매물종류
# 0     37.527777  127.051033  아파트분양권
# 1     37.527777  127.051033  아파트분양권
# 2     37.527777  127.051033  아파트분양권
# 3     37.532241  126.995184     재개발
# 4     37.525286  126.997217     재개발
# ...         ...         ...     ...
# 5549  36.118243  128.351125     재건축
# 5550  35.934358  126.966284     재건축
# 5551  37.446515  129.180128  아파트분양권
# 5552  36.118267  128.350748     재건축
# 5553  35.935140  126.966251     재건축
#
# [5554 rows x 17 columns]

# %%
df1 = pd.read_sql("SELECT * FROM 'total'", rcon, index_col='매물코드')
# df1.to_sql(name="total_220826", con=rcon)
df1
# Out:
#             index        지역코드   시도명      지역명   매물정보                  단지명  \
# 매물코드
# 2407678506      0  4825012400  경상남도      김해시  NDOC1        김해장유역한라비발디센트로
# 2405388188      1  4311325000  충청북도  청주시 흥덕구    DOC  오송역파라곤센트럴시티2차(민간임대)
# 2407356290      2  4617010200  전라남도      나주시  NDOC1            나주역자이리버파크
# 2403965961      3  4311425300  충청북도  청주시 청원구    DOC            더샵오창프레스티지
# 2407586414      4  1168010400   서울시      강남구    TEL               에테르노청담
# ...           ...         ...   ...      ...    ...                  ...
# 2403904418  42656  5214011100  전라북도      익산시  NDOC1                   세경
# 2407579712  42657  5214011100  전라북도      익산시    DOC                   세경
# 2407361800  42658  4711325000  경상북도   포항시 북구  NDOC1              한화포레나포항
# 2404076601  42659  4688025000  전라남도      장성군    DOC  대광로제비앙장성센텀스카이(민간임대)
# 2407979685  42660  4711325000  경상북도   포항시 북구   NONE              힐스테이트초곡
#
#                동 매물방식    매물종류  공급면적  ...  \
# 매물코드                                 ...
# 2407678506  103동   매매  아파트분양권   111  ...
# 2405388188  303동   매매  아파트분양권   112  ...
# 2407356290  110동   매매  아파트분양권   110  ...
# 2403965961  101동   매매  아파트분양권   140  ...
# 2407586414    1동   매매  아파트분양권   567  ...
# ...          ...  ...     ...   ...  ...
# 2403904418   13동   매매     재건축    27  ...
# 2407579712   13동   매매     재건축    27  ...
# 2407361800  102동   매매  아파트분양권   142  ...
# 2404076601  103동   매매  아파트분양권   113  ...
# 2407979685  115동   매매  아파트분양권   112  ...
#
#                                                   특이사항       확인매물   거래가(만)  \
# 매물코드
# 2407678506                              남서향 조망좋고 살기좋은집  24.02.15.    40891
# 2405388188                      급매 ,초등,중학교 바로 앞, 남향 RR  24.01.31.    32902
# 2407356290                               전망트임 확장,옵션비포함  24.02.14.    31689
# 2403965961                                    막힘없는 공원뷰  24.01.23.    65000
# 2407586414             첫입주 넓은정원 듀플렉스타입  오피치네굴로주방 커스텀세대  24.02.15.  3200000
# ...                                                ...        ...      ...
# 2403904418                두산건설 모델하우스오픈  동산동 최고의 위치 재건축  24.01.23.     3000
# 2407579712                     재건축 입주권 101동 3층 59타입 확정  24.02.15.     2500
# 2407361800                                        None  24.02.14.     2386
# 2404076601                    테라스 구조. 단지조경. 25년2월 입주예정  24.01.23.     2100
# 2407979685  분양권 초급매 마피3천\r\n초곡힐스테이트 34A 방3,화2, 남서향, 24  24.02.16.        0
#
#                   한글거래가액                                 태그            부동산  \
# 매물코드
# 2407678506  4,089억 1,000     ['2년이내', '방세개', '화장실두개', '고층']    최상미공인중개사사무소
# 2405388188  3,290억 2,000       ['2년이내', '대단지', '급매', '방세개']   지웰루비공인중개사사무소
# 2407356290  3,168억 9,927  ['2년이내', '대단지', '방네개이상', '화장실두개']        비전공인중개사
# 2403965961  2,654억 2,000   ['2년이내', '대형평수', '방세개', '화장실두개']     보라공인중개사사무소
# 2407586414          320억    ['2년이내', '마당', '대형평수', '방네개이상']    네스트공인중개사사무소
# ...                  ...                                ...            ...
# 2403904418         3,000    ['25년이상', '필로티', '소형평수', '방두개']  제일풍경채공인중개사사무소
# 2407579712         2,500  ['25년이상', '소형평수', '방두개', '화장실한개']     공인중개사사무소선우
# 2407361800         2,386   ['2년이내', '대단지', '대형평수', '방네개이상']    더조은부동산중개사무소
# 2404076601         2,100    ['2년이내', '테라스', '화장실두개', '방세개']  벧엘부동산공인중개사사무소
# 2407979685          None       ['2년이내', '대단지', '급매', '방세개']     서광공인중개사사무소
#
#            매물방향         위도          경도        거래가재산정
# 매물코드
# 2407678506  남서향  35.209777  128.827569  4.192775e+04
# 2405388188   남향  36.619945  127.310082  3.435115e+04
# 2407356290  남동향  35.015469  126.723380  3.796527e+04
# 2403965961  남동향  36.711716  127.433013  6.310000e+04
# 2407586414  북동향  37.527777  127.051033  3.200000e+06
# ...         ...        ...         ...           ...
# 2403904418   남향  35.935140  126.966251  3.000000e+03
# 2407579712   남향  35.935140  126.966251  3.000000e+03
# 2407361800   남향  36.070514  129.331788  4.850874e+04
# 2404076601  남서향  35.306693  126.790788  2.142667e+04
# 2407979685  남서향  36.092467  129.336112  3.545965e+04
#
# [42661 rows x 22 columns]

# %%
rcon.close()
