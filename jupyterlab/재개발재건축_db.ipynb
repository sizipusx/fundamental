# %%
import sqlite3
import pandas as pd

rcon = sqlite3.connect('C:/Users/sizip/fundamental/files/rebuild_house.db')

# %%
file_path = "C:/Users/sizip/OneDriveData/개인/data/부동산 기본 파일/매물시세/2023-11-04_재개발분양권_전체시세.xlsx"
rebuild_dict = pd.ExcelFile(file_path)
total_df =  rebuild_dict.parse("Sheet2", parse_dates=False) # dtype={'구분': str})
sum_df =  rebuild_dict.parse("Sheet3", parse_dates=False) #, dtype={'구분': str})
total_df.tail()
# Out:
#              매물코드        지역코드   시도명     지역명   매물정보               단지명     동  \
# 41057  2346863461  4514011100  전라북도     익산시    DOC                세경   13동
# 41058  2346647910  4514011100  전라북도     익산시    DOC                세경   13동
# 41059  2346709291  4514011100  전라북도     익산시    DOC                세경   13동
# 41060  2345477291  5115036000   강원도     강릉시    DOC  강릉호반베르디움오션(민간임대)  101동
# 41061  2346257432  4711325000  경상북도  포항시 북구  NDOC1           힐스테이트초곡  101동
#
#       매물방식    매물종류 공급면적  ...                                     특이사항  \
# 41057   매매     재건축   27  ...                                      NaN
# 41058   매매     재건축   27  ...                   급매 106동 고층  59A타입 당첨세대
# 41059   매매     재건축   27  ...                  재건축 입주권 101동 3층 59타입 확정
# 41060   매매  아파트분양권   82  ...  무피,1억9300만,에4대,11월10일부터 입주시작,세컨,투자 부담없이
# 41061   매매  아파트분양권   80  ...                       마피1000, 무옵션 매물입니다.
#
#             확인매물 거래가(만) 한글거래가액                                 태그  \
# ...

# %%
# import pandas as pd
# df = pd.read_csv('/content/2022-09-18_재개발분양권_매물요약.csv')
sum_df.to_sql(name="sum", con=rcon, if_exists='replace')
total_df.to_sql(name="total", con=rcon, if_exists='replace')
# Out:
# c:\Anaconda3\lib\site-packages\pandas\core\generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
rdf = pd.read_sql("SELECT * FROM 'sum'", rcon)
rdf
# Out:
#       index  Unnamed: 0                   단지명  공급면적          지역코드   시도명  \
# 0         0           0             나주역자이리버파크   174  4.617010e+09  전라남도
# 1         1           0  용인경남아너스빌디센트H2BL(1단지)   111  4.146136e+09   경기도
# 2         2           1         향남역한양수자인디에스티지   110  4.159026e+09   경기도
# 3         3           1             신진주역세권우미린   112  4.817013e+09  경상남도
# 4         4           2          e편한세상군산디오션루체   110  4.513014e+09  전라북도
# ...     ...         ...                   ...   ...           ...   ...
# 5880   5880        1096                 주공1단지    42  4.715011e+09  경상북도
# 5881   5881        1097                    세경    58  4.514011e+09  전라북도
# 5882   5882        1098                  한우2차    49  4.719011e+09  경상북도
# 5883   5883        1099                  한우2차    40  4.719011e+09  경상북도
# 5884   5884        1100                    세경    27  4.514011e+09  전라북도
#
#             전용면적  공급면적(평)      공급평당가(만)        거래가(만)  물건수        최고값  \
# ...

# %%
df1 = pd.read_sql("SELECT * FROM 'total'", rcon, index_col='매물코드')
# df1.to_sql(name="total_220826", con=rcon)
df1
# Out:
#             index        지역코드   시도명      지역명   매물정보                   단지명  \
# 매물코드
# 2345007877      0  4817013100  경상남도      진주시   NONE             신진주역세권우미린
# 2347447717      1  4159025900   경기도      화성시    DOC         향남역한양수자인디에스티지
# 2343959844      2  4817013100  경상남도      진주시    DOC             신진주역세권데시앙
# 2342903940      3  4146136000   경기도  용인시 처인구   NONE  용인경남아너스빌디센트H2BL(1단지)
# 2345569916      4  3171025600   울산시      울주군    DOC          온양발리한양립스더퍼스트
# ...           ...         ...   ...      ...    ...                   ...
# 2346863461  41057  4514011100  전라북도      익산시    DOC                    세경
# 2346647910  41058  4514011100  전라북도      익산시    DOC                    세경
# 2346709291  41059  4514011100  전라북도      익산시    DOC                    세경
# 2345477291  41060  5115036000   강원도      강릉시    DOC      강릉호반베르디움오션(민간임대)
# 2346257432  41061  4711325000  경상북도   포항시 북구  NDOC1               힐스테이트초곡
#
#                동 매물방식    매물종류 공급면적  ...  \
# ...

# %%
rcon.close()
